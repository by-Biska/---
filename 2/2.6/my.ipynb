# %%
2**13 / (7*256)
# Out:
# 4.571428571428571

# %%
(344 * 65536) /1024
# Out:
# 22016.0

# %%
(238 * 39424) / 1024
# Out:
# 9163.0

# %%
(1056 * 3840) / 1024
# Out:
# 3960.0

# %%
((80 * 2**13)*1.65) / (512*750)
# Out:
# 2.816

# %%
s = "22" + "1" * 2023 + "22"
while "211" in s or "112" in s:
  s= s.replace("11", "1" ,1)
  if "21" in s:
    s= s.replace("21", "12", 1)
  else:
    s= s.replace("12", "1", 1)
print(s)
# Out:
# 121222

# %%
n = 4 * 25**2022 - 2 * 5**2000 + 125**1011 - 3 * 5**100 - 660
k = 0
while n > 0:
    if n % 5 == 4:
        k += 1
    n = n // 5
print(k)
# Out:
# 3028

# %%
for i in range(1000):
  n = i
  while n > 0:
    p =  % 5
    n//=11

# %%
s = 9**11 * 81**5 - 27**3 -27
k = 0
while s> 0:
  if s % 3 == 2:
    k += 1
  s //= 3
print(k)
# Out:
# 38

# %%
s = 16**1003 + 8**405 - 2 ** 239 + 43
print(str(bin(s)).count("0"))
# Out:
# 3033

# %%
for n in range(10001):
  s = 343**8 + 49**2 - n
  k= 0
  while s:
    if s % 7 ==0:
      k+=1
    s//= 7
  if k == 21:
    print(n)
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 43
# 44
# 45
# 46
# 47
# 48
# 56
# 63
# 70
# 77
# 84
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 105
# 112
# 119
# 126
# 133
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 154
# 161
# 168
# 175
# 182
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 203
# 210
# 217
# 224
# 231
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 252
# 259
# 266
# 273
# 280
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 295
# 296
# 297
# 298
# 299
# 300
# 302
# 303
# 304
# 305
# 306
# 307
# 309
# 310
# 311
# 312
# 313
# 314
# 316
# 317
# 318
# 319
# 320
# 321
# 323
# 324
# 325
# 326
# 327
# 328
# 330
# 331
# 332
# 333
# 334
# 335
# 350
# 357
# 364
# 371
# 378
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 399
# 406
# 413
# 420
# 427
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 448
# 455
# 462
# 469
# 476
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 497
# 504
# 511
# 518
# 525
# 532
# 533
# 534
# 535
# 536
# 537
# 538
# 546
# 553
# 560
# 567
# 574
# 581
# 582
# 583
# 584
# 585
# 586
# 587
# 595
# 602
# ...

# %%
"0b123124"[2:]
# Out:
# '123124'

# %%
s= 4**2022 - 6*4**522+5*64**510 - 3*2**330-100
k=0
while s:
  if s % 8 == 7:
    k+=1
  s//= 8
print(k)
# Out:
# 1015

# %%
s = 2022 * "1"
while "11111" in s or "555" in s:
  if "11111" in s:
    s = s.replace("11111", "555", 1)
  else:
    s = s.replace("555", "5", 1)
print(s)
# Out:
# 5511

# %%
s = 1331**650 - 55J*121**610 + 77*11**510-3*11**100 - 221
while s:
  if s%

# %%
int("100000", 4)
# Out:
# 1024

# %%
# s = 6 * 343**1156 - 5 * 49**1147 + 4*7**1153 - 875
# def f(n):
#   st =''
#   while n > 0:
#     st = str(n %7) + st
#     n//=7
#   return (st)
# a = str(f(s))
# n = 0
# sum(map(int,str(f(s))))
x= 6*343**1156-5*49**1147+4*7**1153-875
print (x)
s=0
while x>0:
    a = x%7
    s += a
    x = x//7
print (s)
# Out:
# 13950

# %%
sum(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 sum(123)
#
# TypeError: 'int' object is not iterable

# %%
4**4
# Out:
# 256

# %%
int("000155", 6)
# Out:
# 71

# %%
(3**3 * 2) + (2**2 * 3**2) + 2**3 * 3 + 2**3 *3 + 2**2 * 3**2
# Out:
# 174
