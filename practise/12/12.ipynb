# %% [markdown]
# 5649

# %%
x = 0
for k in range(100, 201):
  for m in range(100, 201):
    for n in range(100, 201):
      x = n * 2 + 3 * k + m
      if x == 1190:
        print(k, m, n)
# Out:
# 197 199 200
# 198 196 200
# 198 198 199
# 198 200 198
# 199 193 200
# 199 195 199
# 199 197 198
# 199 199 197
# 200 190 200
# 200 192 199
# 200 194 198
# 200 196 197
# 200 198 196
# 200 200 195

# %% [markdown]
# 5648

# %%
s = 0
for x in range(41, 100000):
  s = 2 * x + 4 * x
  if str(s)[::-1][:2] == "77":
    print(x)

# %%
s = 12345 
type(str(s)[::-1][:2][::-1])
# Out:
# str

# %%
s = 2 * 46 + 4 * 46
print(s)
# Out:
# 276

# %% [markdown]
# 5420

# %%
s = 203 * "1" + "2"
while "111" in s or "222" in s:
  if "111" in s:
    s = s.replace("111", "22", 1)
  elif "222" in s:
    s = s.replace("222", "11", 1)
  print(s)
# Out:
# 22111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111112
# 2222111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111112
# 222222111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111112
# 22222222111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111112
# ...
